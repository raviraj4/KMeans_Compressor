# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.array([7,8,20,8,7])

# %%
plt.hist(arr)
# Out:
# (array([4., 0., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([ 7. ,  8.3,  9.6, 10.9, 12.2, 13.5, 14.8, 16.1, 17.4, 18.7, 20. ]),
#  <BarContainer object of 10 artists>)
